# %%
# import python libraries

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('Diwali_Sales_Data.csv',encoding = 'unicode_escape')
df
# Out:
#        User_ID    Cust_name Product_ID Gender  Age  Marital_Status  \
# 0      1002903    Sanskriti  P00125942      F   28               0
# 1      1000732       Kartik  P00110942      F   35               1
# 2      1001990        Bindu  P00118542      F   35               1
# 3      1001425       Sudevi  P00237842      M   16               0
# 4      1000588         Joni  P00057942      M   28               1
# ...        ...          ...        ...    ...  ...             ...
# 11246  1000695      Manning  P00296942      M   19               1
# 11247  1004089  Reichenbach  P00171342      M   33               0
# 11248  1001209        Oshin  P00201342      F   40               0
# 11249  1004023       Noonan  P00059442      M   37               0
# 11250  1002744      Brumley  P00281742      F   19               0
#
#                 State      Zone       Occupation Product_Category  Orders  \
# 0         Maharashtra   Western       Healthcare             Auto       1
# ...

# %%
# to know how many rows and columns
df.shape
# Out:
# (11251, 14)

# %%
# Check if any NA or missing values
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11251 entries, 0 to 11250
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11251 non-null  int64
#  1   Cust_name         11251 non-null  object
#  2   Product_ID        11251 non-null  object
#  3   Gender            11251 non-null  object
#  4   Age               11251 non-null  int64
#  5   Marital_Status    11251 non-null  int64
#  6   State             11251 non-null  object
#  7   Zone              11251 non-null  object
#  8   Occupation        11251 non-null  object
#  9   Product_Category  11251 non-null  object
#  10  Orders            11251 non-null  int64
#  11  Amount            11239 non-null  float64
#  12  Status            0 non-null      float64
#  13  Unnamed           0 non-null      float64
# dtypes: float64(3), int64(4), object(7)
# memory usage: 1.2+ MB

# %%
# Removing unnecessary columns
df.drop(['Status','Unnamed'],axis=1,inplace=True)
df.head()
# Out:
#    User_ID  Cust_name Product_ID Gender  Age  Marital_Status           State  \
# 0  1002903  Sanskriti  P00125942      F   28               0     Maharashtra
# 1  1000732     Kartik  P00110942      F   35               1  Andhra Pradesh
# 2  1001990      Bindu  P00118542      F   35               1   Uttar Pradesh
# 3  1001425     Sudevi  P00237842      M   16               0       Karnataka
# 4  1000588       Joni  P00057942      M   28               1         Gujarat
#
#        Zone       Occupation Product_Category  Orders   Amount
# 0   Western       Healthcare             Auto       1  23952.0
# 1  Southern             Govt             Auto       3  23934.0
# 2   Central       Automobile             Auto       3  23924.0
# 3  Southern     Construction             Auto       2  23912.0
# 4   Western  Food Processing             Auto       2  23877.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11251 entries, 0 to 11250
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11251 non-null  int64
#  1   Cust_name         11251 non-null  object
#  2   Product_ID        11251 non-null  object
#  3   Gender            11251 non-null  object
#  4   Age               11251 non-null  int64
#  5   Marital_Status    11251 non-null  int64
#  6   State             11251 non-null  object
#  7   Zone              11251 non-null  object
#  8   Occupation        11251 non-null  object
#  9   Product_Category  11251 non-null  object
#  10  Orders            11251 non-null  int64
#  11  Amount            11239 non-null  float64
# dtypes: float64(1), int64(4), object(7)
# memory usage: 1.0+ MB

# %%
# Checking how many null values
pd.isnull(df).sum()
# Out:
# User_ID              0
# Cust_name            0
# Product_ID           0
# Gender               0
# Age                  0
# Marital_Status       0
# State                0
# Zone                 0
# Occupation           0
# Product_Category     0
# Orders               0
# Amount              12
# dtype: int64

# %%
# calculating the mean value for each category and fill NA with mean from that category
df['Amount']=df.groupby('Product_Category')['Amount'].transform(lambda x: x.fillna(x.mean()))

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11251 entries, 0 to 11250
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11251 non-null  int64
#  1   Cust_name         11251 non-null  object
#  2   Product_ID        11251 non-null  object
#  3   Gender            11251 non-null  object
#  4   Age               11251 non-null  int64
#  5   Marital_Status    11251 non-null  int64
#  6   State             11251 non-null  object
#  7   Zone              11251 non-null  object
#  8   Occupation        11251 non-null  object
#  9   Product_Category  11251 non-null  object
#  10  Orders            11251 non-null  int64
#  11  Amount            11251 non-null  float64
# dtypes: float64(1), int64(4), object(7)
# memory usage: 1.0+ MB

# %%
# Changing the data type of Amount column from Float to Int
df['Amount'] = df['Amount'].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11251 entries, 0 to 11250
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11251 non-null  int64
#  1   Cust_name         11251 non-null  object
#  2   Product_ID        11251 non-null  object
#  3   Gender            11251 non-null  object
#  4   Age               11251 non-null  int64
#  5   Marital_Status    11251 non-null  int64
#  6   State             11251 non-null  object
#  7   Zone              11251 non-null  object
#  8   Occupation        11251 non-null  object
#  9   Product_Category  11251 non-null  object
#  10  Orders            11251 non-null  int64
#  11  Amount            11251 non-null  int32
# dtypes: int32(1), int64(4), object(7)
# memory usage: 1011.0+ KB

# %%
# Rename the column
df.rename({'Marital_Status':'Married'},axis=1,inplace=True)

# %%
df.head()
# Out:
#    User_ID  Cust_name Product_ID Gender  Age  Married           State  \
# 0  1002903  Sanskriti  P00125942      F   28        0     Maharashtra
# 1  1000732     Kartik  P00110942      F   35        1  Andhra Pradesh
# 2  1001990      Bindu  P00118542      F   35        1   Uttar Pradesh
# 3  1001425     Sudevi  P00237842      M   16        0       Karnataka
# 4  1000588       Joni  P00057942      M   28        1         Gujarat
#
#        Zone       Occupation Product_Category  Orders  Amount
# 0   Western       Healthcare             Auto       1   23952
# 1  Southern             Govt             Auto       3   23934
# 2   Central       Automobile             Auto       3   23924
# 3  Southern     Construction             Auto       2   23912
# 4   Western  Food Processing             Auto       2   23877

# %%
# Its a user define function for Grouping the age column
def age_gp(Age):
    if Age<= 17:
        return '0-17'
    elif Age<= 25:
        return '18-25'
    elif Age<= 35:
        return '26-35'
    elif Age<= 45:
        return '36-45'
    elif Age<= 55:
        return '46-55'
    else:
        return '55+'

# %%
# creating a age group column by using the created function 
df['Age_Group'] = df['Age'].apply(age_gp)

# %%
df.head()
# Out:
#    User_ID  Cust_name Product_ID Gender  Age  Married           State  \
# 0  1002903  Sanskriti  P00125942      F   28        0     Maharashtra
# 1  1000732     Kartik  P00110942      F   35        1  Andhra Pradesh
# 2  1001990      Bindu  P00118542      F   35        1   Uttar Pradesh
# 3  1001425     Sudevi  P00237842      M   16        0       Karnataka
# 4  1000588       Joni  P00057942      M   28        1         Gujarat
#
#        Zone       Occupation Product_Category  Orders  Amount Age_Group
# 0   Western       Healthcare             Auto       1   23952     26-35
# 1  Southern             Govt             Auto       3   23934     26-35
# 2   Central       Automobile             Auto       3   23924     26-35
# 3  Southern     Construction             Auto       2   23912      0-17
# 4   Western  Food Processing             Auto       2   23877     26-35

# %% [markdown]
# #  Exploratory Data Analysis (EDA)

# %% [markdown]
# ## Gender

# %%
df.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age', 'Married',
#        'State', 'Zone', 'Occupation', 'Product_Category', 'Orders', 'Amount',
#        'Age_Group'],
#       dtype='object')

# %%
ax_gd = sns.countplot(x='Gender',data=df,hue = 'Gender')
for bars in ax_gd.containers:
    ax_gd.bar_label(bars)

# %%
ax_am = df.groupby(['Gender'],as_index=False)['Amount'].sum().sort_values(by='Amount',ascending = False)
sns.barplot(x='Gender',y='Amount',data = ax_am,hue = 'Gender')
# Out:
# <Axes: xlabel='Gender', ylabel='Amount'>

# %% [markdown]
# ### From above graphs we can see that most of the buyers are Female and even purchasing power of Female are greater than men

# %% [markdown]
# # Age

# %%
df.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age', 'Married',
#        'State', 'Zone', 'Occupation', 'Product_Category', 'Orders', 'Amount',
#        'Age_Group'],
#       dtype='object')

# %%
ag_ge = sns.countplot(x='Age_Group',hue='Gender',data = df)
for bars in ag_ge.containers:
    ag_ge.bar_label(bars)

# %%
ag_am = df.groupby(['Age_Group'],as_index = False)['Amount'].sum().sort_values(by = 'Amount',ascending=False)
sns.barplot(x='Age_Group',y='Amount',data = ag_am,hue='Age_Group')
# Out:
# <Axes: xlabel='Age_Group', ylabel='Amount'>

# %% [markdown]
# ### From above graphs we can see that most of the buyers are age group between 26-35 yrs Female

# %% [markdown]
# # State

# %%
df.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age', 'Married',
#        'State', 'Zone', 'Occupation', 'Product_Category', 'Orders', 'Amount',
#        'Age_Group'],
#       dtype='object')

# %%
st_or = df.groupby('State',as_index = False)['Orders'].sum().sort_values(by = 'Orders',ascending = False).head(10)
sns.set(rc={'figure.figsize':(17,5)})
sns.barplot(x='State',y = 'Orders',data = st_or,hue = 'State')
# Out:
# <Axes: xlabel='State', ylabel='Orders'>

# %%
st_am = df.groupby('State',as_index = False)['Amount'].sum().sort_values(by = 'Amount',ascending = False).head(10)
sns.set(rc={'figure.figsize':(17,5)})
sns.barplot(x='State',y = 'Amount',data = st_am,hue = 'State')
# Out:
# <Axes: xlabel='State', ylabel='Amount'>

# %% [markdown]
# ### From above graphs we can see that most of the orders & total sales/amount are from Uttar Pradesh, Maharastra, Karnataka respectively

# %% [markdown]
# # Married

# %%
df.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age', 'Married',
#        'State', 'Zone', 'Occupation', 'Product_Category', 'Orders', 'Amount',
#        'Age_Group'],
#       dtype='object')

# %%
sns.set(rc={'figure.figsize':(5,5)})
ma_or = sns.countplot(x = 'Married',data = df)
for bars in ma_or.containers:
    ma_or.bar_label(bars)

# %%
sns.set(rc={'figure.figsize':(5,5)})
ma_am = df.groupby(['Married','Gender'],as_index = False)['Amount'].sum().sort_values(by = 'Amount',ascending = False).head(10)
sns.barplot(x='Married',y = 'Amount',data = ma_am,hue='Gender')
# Out:
# <Axes: xlabel='Married', ylabel='Amount'>

# %% [markdown]
# ### From above graphs we can see that most of the buyers are Married (Women) and they have high purchasing power

# %% [markdown]
# # Occupation

# %%
df.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age', 'Married',
#        'State', 'Zone', 'Occupation', 'Product_Category', 'Orders', 'Amount',
#        'Age_Group'],
#       dtype='object')

# %%
sns.set(rc={'figure.figsize':(20,5)})
oc_or = sns.countplot(x= 'Occupation',data = df,hue = 'Occupation')
for bars in oc_or.containers:
    oc_or.bar_label(bars)

# %%
oc_am = df.groupby(['Occupation'],as_index=False)['Amount'].sum().sort_values(by = 'Amount',ascending=False).head(10)
sns.set(rc={'figure.figsize':(20,5)})
sns.barplot(x= 'Occupation', y='Amount',data = oc_am,hue = 'Occupation')
# Out:
# <Axes: xlabel='Occupation', ylabel='Amount'>

# %% [markdown]
# ### From above graphs we can see that most of the buyers are working in IT Sector, Healthcare and Aviation Sector

# %% [markdown]
# # Product Category

# %%
df.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age', 'Married',
#        'State', 'Zone', 'Occupation', 'Product_Category', 'Orders', 'Amount',
#        'Age_Group'],
#       dtype='object')

# %%
sns.set(rc={'figure.figsize':(20,5)})
pc_or = sns.countplot(x = 'Product_Category',data = df,hue = 'Product_Category')
for bars in pc_or.containers:
    pc_or.bar_label(bars)

# %%
pc_am = df.groupby(['Product_Category'],as_index=False)['Amount'].sum().sort_values(by = 'Amount',ascending=False).head(10)
sns.set(rc={'figure.figsize':(20,5)})
sns.barplot(x= 'Product_Category', y='Amount',data = pc_am,hue = 'Product_Category')
# Out:
# <Axes: xlabel='Product_Category', ylabel='Amount'>

# %% [markdown]
# ### From above graphs we can see that most of the sold products are from Food, Clothing, Footwear Category

# %% [markdown]
# # Product_ID of most selling product

# %%
pi_or = df.groupby(['Product_ID'],as_index=False)['Amount'].sum().sort_values(by = 'Amount',ascending=False).head(10)
sns.set(rc={'figure.figsize':(12,3)})
sns.barplot(x= 'Product_ID', y='Amount',data = pi_or)
# Out:
# <Axes: xlabel='Product_ID', ylabel='Amount'>

# %% [markdown]
# # Insights:

# %% [markdown]
# ### Married women age group 26-35 Yrs from Uttar Pradesh,Maharastra and Karnatka working in IT,Healthcare and Aviation are more likely to buy Products From Foods, Clothing and Footwear Category.
